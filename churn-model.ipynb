# %% [markdown]
# # **Churn modelling using ANN**

# %% [markdown]
# ## Setting up the development environment by importing required libraries and modules.

# %%
import pandas as pd 
import numpy as np 
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder, OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score

# %% [markdown]
# #### Numpy: It will provide the support for efficient numerical computation.
# #### Pandas: It is convenient library that supports dataframes. Working with pandas will bring ease in many crucial data operations.
# ### sklearn.preprocessing:
# ####  * LabelEncoder:LabelEncoder encode labels with a value between 0 and n_classes-1 where n is the number of distinct labels.
# ####  * OneHotEncoder:One-hot encoding is used in machine learning as a method to quantify categorical data. In short, this method produces a vector with length equal to the number of categories in the data set.
# #### * StandardScaler:Standardize features by removing the mean and scaling to unit variance.
# ### sklearn.compose:
# #### * This estimator allows different columns or column subsets of the input to be transformed separately and the features generated by each transformer will be concatenated to form a single feature space.
# ### sklearn.model_selection:
# #### * train_test_split: It splits data in training and test set as x_train,x_test,y_train,y_test.
# ### sklearn.metrics:
# #### * confusion_matrix:Compute confusion matrix to evaluate the accuracy of a classification.
# #### * accuracy_score:In multilabel classification, this function computes subset accuracy: the set of labels predicted for a sample must exactly match the corresponding set of labels in y_true.

# %% [markdown]
# ## importing dataset

# %%
data=pd.read_csv("../input/churnmodelling/Churn_Modelling.csv")

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.shape
# Out:
# (10000, 14)

# %% [markdown]
# ## About dataset
#  ### * This data set contains details of a bank's customers and the target variable is a binary variable reflecting the fact whether the customer left the bank (closed his account) or he continues to be a customer.
#  ### * Dataset consist of 14 columns out of which 13 are independent variable and 14th column is dependent variabll.
#  ### * It consist of 10000 rows

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## seprating independent variable (x) and dependent variable(y) .

# %%
x=data.iloc[:,3:-1]
y=data.iloc[:,-1]
print("x:")
print(x.head())
print("  y:")
print(y.head())
# Out:
# x:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10
#   y:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %% [markdown]
# ### As we can see we have two categorical features 1:Geography ,2:Gender
# ### checking there unique names so to encode them.

# %%
print(x.iloc[:,1].unique())
print(x.iloc[:,2].unique())
# Out:
# ['France' 'Spain' 'Germany']
# ['Female' 'Male']

# %% [markdown]
# ### Coverting the data in numpy-array by taking only the values of each column

# %%
x=data.iloc[:,3:-1].values
y=data.iloc[:,-1].values
x
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %% [markdown]
# ### From the above we can see that gender has two values(male and females) so we will do label encoding for gender column and Geography column have 3 values (France,Spain,Germany) so we will do OneHotEndcoding for that.

# %%
Le=LabelEncoder()
x[:,2]=Le.fit_transform(x[:,2])
print(Le.classes_)
# Out:
# ['Female' 'Male']

# %%
ct=ColumnTransformer(transformers=[( 'OneHotEncoder',OneHotEncoder(), [1])], remainder='passthrough')
x=np.array(ct.fit_transform(x))
x
# Out:
# array([[1.0, 0.0, 0.0, ..., 1, 1, 101348.88],
#        [0.0, 0.0, 1.0, ..., 0, 1, 112542.58],
#        [1.0, 0.0, 0.0, ..., 1, 0, 113931.57],
#        ...,
#        [1.0, 0.0, 0.0, ..., 0, 1, 42085.58],
#        [0.0, 1.0, 0.0, ..., 1, 0, 92888.52],
#        [1.0, 0.0, 0.0, ..., 1, 0, 38190.78]], dtype=object)

# %% [markdown]
# ### So now after encoding we get values as follow:
#  ### female:0 , Male:1
#  ### France: 1 0 0,  Spain: 0 0 1  , Germany: 0 1 0

# %% [markdown]
# ### Spliting data in train test split.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Scaling the training data so that it can be input in neural networks

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %% [markdown]
# # Building Artificial Neural Network

# %% [markdown]
# ## Initializing ANN

# %%
ann=tf.keras.models.Sequential()

# %% [markdown]
# ##  hidden Layers

# %%
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))

# %% [markdown]
# ## Output Layer

# %%
ann.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %% [markdown]
# # Training ANN

# %% [markdown]
# ## Compiling ANN

# %%
ann.compile(optimizer='adam',loss='binary_crossentropy' ,metrics=['accuracy'])

# %% [markdown]
# ## Fitting ANN

# %%
ann.fit(x_train,y_train,batch_size=64,epochs=200)
# Out:
# Epoch 1/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.6225 - accuracy: 0.7113
# Epoch 2/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.5160 - accuracy: 0.7952
# Epoch 3/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4836 - accuracy: 0.7960
# Epoch 4/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4646 - accuracy: 0.7960
# Epoch 5/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4509 - accuracy: 0.7969
# Epoch 6/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4423 - accuracy: 0.8040
# Epoch 7/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.8049
# Epoch 8/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4336 - accuracy: 0.8044
# Epoch 9/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4313 - accuracy: 0.8058
# Epoch 10/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4295 - accuracy: 0.8064
# Epoch 11/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4281 - accuracy: 0.8084
# Epoch 12/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4269 - accuracy: 0.8081
# Epoch 13/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4255 - accuracy: 0.8087
# Epoch 14/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4242 - accuracy: 0.8110
# Epoch 15/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4232 - accuracy: 0.8129
# Epoch 16/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4219 - accuracy: 0.8145
# Epoch 17/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4205 - accuracy: 0.8165
# Epoch 18/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4189 - accuracy: 0.8202
# Epoch 19/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4177 - accuracy: 0.8232
# Epoch 20/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4163 - accuracy: 0.8226
# Epoch 21/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4153 - accuracy: 0.8242
# Epoch 22/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.8259
# Epoch 23/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4129 - accuracy: 0.8270
# Epoch 24/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4118 - accuracy: 0.8282
# Epoch 25/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4108 - accuracy: 0.8280
# Epoch 26/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8295
# Epoch 27/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4092 - accuracy: 0.8282
# Epoch 28/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4087 - accuracy: 0.8313
# Epoch 29/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8303
# Epoch 30/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4074 - accuracy: 0.8325
# Epoch 31/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4068 - accuracy: 0.8322
# Epoch 32/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4065 - accuracy: 0.8314
# Epoch 33/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4057 - accuracy: 0.8321
# Epoch 34/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4052 - accuracy: 0.8334
# Epoch 35/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4048 - accuracy: 0.8334
# Epoch 36/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4041 - accuracy: 0.8354
# Epoch 37/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8349
# Epoch 38/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8349
# Epoch 39/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8364
# Epoch 40/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4017 - accuracy: 0.8357
# Epoch 41/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4012 - accuracy: 0.8357
# Epoch 42/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8353
# Epoch 43/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.4000 - accuracy: 0.8360
# Epoch 44/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3997 - accuracy: 0.8356
# Epoch 45/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3991 - accuracy: 0.8365
# Epoch 46/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3990 - accuracy: 0.8340
# Epoch 47/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.8359
# Epoch 48/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8359
# Epoch 49/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3972 - accuracy: 0.8363
# Epoch 50/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3971 - accuracy: 0.8367
# Epoch 51/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3963 - accuracy: 0.8367
# Epoch 52/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3961 - accuracy: 0.8367
# Epoch 53/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3957 - accuracy: 0.8369
# Epoch 54/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8363
# Epoch 55/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3947 - accuracy: 0.8366
# Epoch 56/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8366
# Epoch 57/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8361
# Epoch 58/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3938 - accuracy: 0.8366
# Epoch 59/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.8365
# Epoch 60/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3930 - accuracy: 0.8361
# Epoch 61/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.8372
# Epoch 62/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8372
# Epoch 63/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3919 - accuracy: 0.8370
# Epoch 64/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3916 - accuracy: 0.8367
# Epoch 65/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3916 - accuracy: 0.8384
# Epoch 66/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3908 - accuracy: 0.8393
# Epoch 67/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3907 - accuracy: 0.8406
# Epoch 68/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3903 - accuracy: 0.8394
# Epoch 69/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3901 - accuracy: 0.8400
# Epoch 70/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3897 - accuracy: 0.8405
# Epoch 71/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3895 - accuracy: 0.8396
# Epoch 72/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3892 - accuracy: 0.8407
# Epoch 73/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.8410
# Epoch 74/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3884 - accuracy: 0.8419
# Epoch 75/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3877 - accuracy: 0.8419
# Epoch 76/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3868 - accuracy: 0.8424
# Epoch 77/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3860 - accuracy: 0.8424
# Epoch 78/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3856 - accuracy: 0.8439
# Epoch 79/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3848 - accuracy: 0.8428
# Epoch 80/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3838 - accuracy: 0.8426
# Epoch 81/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3829 - accuracy: 0.8438
# Epoch 82/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8446
# Epoch 83/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3810 - accuracy: 0.8446
# Epoch 84/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8454
# Epoch 85/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3790 - accuracy: 0.8449
# Epoch 86/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3778 - accuracy: 0.8441
# Epoch 87/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3753 - accuracy: 0.8476
# Epoch 88/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3720 - accuracy: 0.8478
# Epoch 89/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3683 - accuracy: 0.8482
# Epoch 90/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3651 - accuracy: 0.8505
# Epoch 91/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8497
# Epoch 92/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3599 - accuracy: 0.8520
# Epoch 93/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3575 - accuracy: 0.8521
# Epoch 94/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3559 - accuracy: 0.8524
# Epoch 95/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3541 - accuracy: 0.8540
# Epoch 96/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3527 - accuracy: 0.8553
# Epoch 97/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3510 - accuracy: 0.8544
# Epoch 98/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3508 - accuracy: 0.8559
# Epoch 99/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8555
# Epoch 100/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3486 - accuracy: 0.8568
# Epoch 101/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3474 - accuracy: 0.8581
# Epoch 102/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3475 - accuracy: 0.8565
# Epoch 103/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3473 - accuracy: 0.8577
# Epoch 104/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3451 - accuracy: 0.8581
# Epoch 105/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3454 - accuracy: 0.8577
# Epoch 106/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3448 - accuracy: 0.8591
# Epoch 107/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3448 - accuracy: 0.8583
# Epoch 108/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3446 - accuracy: 0.8585
# Epoch 109/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.8585
# Epoch 110/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.8590
# Epoch 111/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3435 - accuracy: 0.8593
# Epoch 112/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3429 - accuracy: 0.8580
# Epoch 113/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3432 - accuracy: 0.8594
# Epoch 114/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3425 - accuracy: 0.8577
# Epoch 115/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8596
# Epoch 116/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.8587
# Epoch 117/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8596
# Epoch 118/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3420 - accuracy: 0.8591
# Epoch 119/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3415 - accuracy: 0.8594
# Epoch 120/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3416 - accuracy: 0.8577
# Epoch 121/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3410 - accuracy: 0.8589
# Epoch 122/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3407 - accuracy: 0.8596
# Epoch 123/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3405 - accuracy: 0.8591
# Epoch 124/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3399 - accuracy: 0.8618
# Epoch 125/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3395 - accuracy: 0.8583
# Epoch 126/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3392 - accuracy: 0.8601
# Epoch 127/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3397 - accuracy: 0.8600
# Epoch 128/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3395 - accuracy: 0.8610
# Epoch 129/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3394 - accuracy: 0.8577
# Epoch 130/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3389 - accuracy: 0.8594
# Epoch 131/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3389 - accuracy: 0.8584
# Epoch 132/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3391 - accuracy: 0.8605
# Epoch 133/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3380 - accuracy: 0.8594
# Epoch 134/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3386 - accuracy: 0.8591
# Epoch 135/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3390 - accuracy: 0.8606
# Epoch 136/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3380 - accuracy: 0.8606
# Epoch 137/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3380 - accuracy: 0.8590
# Epoch 138/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3382 - accuracy: 0.8597
# Epoch 139/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3376 - accuracy: 0.8609
# Epoch 140/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3377 - accuracy: 0.8605
# Epoch 141/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3367 - accuracy: 0.8611
# Epoch 142/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3373 - accuracy: 0.8597
# Epoch 143/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3363 - accuracy: 0.8610
# Epoch 144/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.8609
# Epoch 145/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8606
# Epoch 146/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3368 - accuracy: 0.8602
# Epoch 147/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3363 - accuracy: 0.8622
# Epoch 148/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3367 - accuracy: 0.8591
# Epoch 149/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3364 - accuracy: 0.8604
# Epoch 150/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8600
# Epoch 151/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3365 - accuracy: 0.8593
# Epoch 152/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3361 - accuracy: 0.8620
# Epoch 153/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3361 - accuracy: 0.8626
# Epoch 154/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3367 - accuracy: 0.8602
# Epoch 155/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.8608
# Epoch 156/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8594
# Epoch 157/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.8621
# Epoch 158/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3361 - accuracy: 0.8622
# Epoch 159/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3353 - accuracy: 0.8620
# Epoch 160/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.8625
# Epoch 161/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3361 - accuracy: 0.8605
# Epoch 162/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3357 - accuracy: 0.8611
# Epoch 163/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3357 - accuracy: 0.8602
# Epoch 164/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.8620
# Epoch 165/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3357 - accuracy: 0.8616
# Epoch 166/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3358 - accuracy: 0.8601
# Epoch 167/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8619
# Epoch 168/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8631
# Epoch 169/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8604
# Epoch 170/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3354 - accuracy: 0.8629
# Epoch 171/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.8602
# Epoch 172/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8636
# Epoch 173/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.8612
# Epoch 174/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8619
# Epoch 175/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8624
# Epoch 176/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3347 - accuracy: 0.8621
# Epoch 177/200
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3343 - accuracy: 0.8611
# Epoch 178/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8600
# Epoch 179/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3345 - accuracy: 0.8641
# Epoch 180/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3346 - accuracy: 0.8640
# Epoch 181/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8619
# Epoch 182/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8616
# Epoch 183/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3345 - accuracy: 0.8639
# Epoch 184/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3346 - accuracy: 0.8616
# Epoch 185/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3350 - accuracy: 0.8611
# Epoch 186/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8612
# Epoch 187/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8618
# Epoch 188/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3353 - accuracy: 0.8597
# Epoch 189/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8631
# Epoch 190/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8614
# Epoch 191/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8606
# Epoch 192/200
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3339 - accuracy: 0.8618
# Epoch 193/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.8616
# Epoch 194/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3340 - accuracy: 0.8597
# Epoch 195/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8614
# Epoch 196/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8608
# Epoch 197/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3334 - accuracy: 0.8634
# Epoch 198/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.8620
# Epoch 199/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8622
# Epoch 200/200
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3335 - accuracy: 0.8621

# %% [markdown]
# ## As we can see that it is giving 86% accuracy

# %% [markdown]
# ## Making prediction and evaluating results.

# %%
y_pred=ann.predict(x_test)
y_pred=(y_pred>0.5)
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %% [markdown]
# ### calculating accuracy and confusion matrix

# %%
cm=confusion_matrix(y_test,y_pred)
print('confusion_matrix:')
print(cm)
accuracy=accuracy_score(y_test,y_pred)
print("acuuracy:",accuracy)
# Out:
# confusion_matrix:
# [[1519   76]
#  [ 213  192]]
# acuuracy: 0.8555

# %% [markdown]
# ### Geography: spain
# ### Credit Score : 600
# ### Gender: Male
# ### Age: 40 years old
# ### Tenure: 3 years
# ### Balance: 60000 usd
# ### Number of Products: 2
# ### Does this customer have a credit card ? Yes
# ### Is this customer an Active Member: Yes
# ### Estimated Salary: 50000 usd

# %%
new_pred=ann.predict(sc.transform(np.array([[1,0,0,600,1,40,3,60000,2,1,1,50000]])))
new_pred=(new_pred>0.5)
print(new_pred)
# Out:
# [[False]]
